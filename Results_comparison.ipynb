# %% [markdown]
# <a href="https://colab.research.google.com/github/RiccardoCozzi96/DeepComedy/blob/main/Results_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Results Comparison
#
# We provide this notebook for:
# * Inspecting a single canto by specifying model and temperature
# *   Reading the results of all the generations of all the models
# *   Finding the best performance for each metric (hendecasyllables, rhymes, etc...)
# * Finding the overall best models

# %% [markdown]
# ##Setup

# %%
import pandas as pd
import numpy as np
import json

# we stored our files on Git
import sys
# !git clone "https://github.com/RiccardoCozzi96/DeepComedy"
# Out:
# fatal: destination path 'DeepComedy' already exists and is not an empty directory.

# %%
path = f"DeepComedy/generated cantos/"
comedy_filename = "DeepComedy/datasets/commedia.txt"
results_filename = "DeepComedy/results.csv"

# %% [markdown]
# ### Some useful functions

# %%
def print_model(model_string, temp=None):
  m = model_string.split("_")
  print("\nencoders\t{}\ndecoders\t{}\ndff     \t{}\nd_model \t{}\nheads   \t{}\nprod epochs\t{}""\ncomedy epochs\t{}"
  .format(m[0], m[1], m[2], m[3], m[4], m[5], m[6]))
  if temp != None:
    print("temperature\t{}".format(temp))

def get_text(model, temp):
  return json.load(open(f"{path}{model}/LOG_{model}.json"))["generations"]["temp_"+temp]

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv(results_filename, index_col=["id"])

# %% [markdown]
# ### Ignore unuseful scores
# Some metrics we tried to implement are not useful or not accurate enough. We ignore them for the moment.

# %%
#TEMP change name for hendec
data["hendec_ratio"] = data["hendec"]
data = data.drop(columns=["hendec"])

# TEMP SUBTRACT AVG_SYL
# data["hendec_correctness"] = [1 - score for score in data["avg_syl"].values]
data = data.drop(columns=["avg_syl"])

#TEMP convert the incorrectness to sigmoid value
data["word_correctness"] = [1+x for x in data.incorr]
data = data.drop(columns=["incorr"])

#TEMP parameters to be ignored
data = data.drop(columns=["plagiar"])
data = data.drop(columns=["n_vers"])

data
# Out:
#                    model  temperature  ...  hendec_ratio  word_correctness
# id                                     ...
# 0    1_1_256_512_4_0_150          0.5  ...          0.87              0.56
# 1    1_1_256_512_4_0_150          0.6  ...          0.90              0.57
# 2    1_1_256_512_4_0_150          0.7  ...          0.90              0.55
# 3    1_1_256_512_4_0_150          0.8  ...          0.92              0.68
# 4    1_1_256_512_4_0_150          0.9  ...          0.90              0.49
# ..                   ...          ...  ...           ...               ...
# 237  7_7_256_512_4_0_150          1.1  ...          0.89              0.72
# 238  7_7_256_512_4_0_150          1.2  ...          0.85              0.68
# 239  7_7_256_512_4_0_150          1.3  ...          0.85              0.62
# 240  7_7_256_512_4_0_150          1.4  ...          0.85              0.65
# 241  7_7_256_512_4_0_150          1.5  ...          0.71              0.63
#
# [242 rows x 6 columns]

# %% [markdown]
# ## Inspect a generated canto

# %%
model = "1_7_256_512_4_0_150"
temp = "0.5"

# show model info and generated text
print_model(model, temp)
print(get_text(model, temp))

# print scores of the selected canto
data.loc[data['model'] == model].loc[data["temperature"] == float(temp)]
# Out:
# encoders	1
# decoders	7
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	0
# comedy epochs	150
# temperature	0.5
#
# àhi quànto a dir qual èra è còsa?.
# ed elli a me: li spirti ché vien canta;
# perche' qui si può dir più óltre riposa.
#
# io t'ho vegnate, ché da se' mandanta,
# nón l'aspetto se' tu de la tua ritesta;
# ma perche' se' fàtta ha più ti dicanta.
#
# rispuos'io lui: ciò ché tu se' dimostrasta
# nón m'è il piànto di cotal ché qui méco
# còl sàngue sùo e de la ménte più grasta.
#
# per men vo di là dal móndo se cieco
# dél càrro è più di sópra ché si puote
# ciò ché 'l móndo nón salir nón regeco.
#
# ma se dal móndo sùo voler vedete,
# la càrca mìa memòria la vìsta spenta,
# da tutta presa, e pòi conosce piete.
#
# al quàle mi grazia, ché sì s'intenta,
# che, se nón fossi, al sapere, scésa
# per li raper esser più dov'è aventata.
#
# qui si rivolge, e qui si riscésa,
# sòn li tuoi dover, da quella selvaggia
# parèa dél tùo parlar sarebbe risposa.
#
# nón lascia mìa dònna cón a più caggia
# sóvra pigliàre occhi, e nón aver latesta,
# in tutte ne la s.u.a. lugiagia.
#
# in tutte parve la gènte ché si prèsta
# m'era vàlle de la dònna ché mi pinche,
# dél mìo dolor, dicendo più s'acdesta.
#
# dél piànto mi fe' già le spalle ànche,
# e queste demon di dìo per mìlle vieni
# dél piànto di là giù per fàme trachele.
#
# e già la tèrra ché chiese di pieni,
# per veder de, io nón ti fe' propinde,
# ché più spiacenza, andando, li sovvenni.
#
# ma perche' più nón te da ch'è s'infonde,
# io diceva, e dél sùo concètto lòco
# nón ha ségno più ché da se' si sponde,
#
# ma tu hài tu così, se dél cieco,
# nón vedrai ché da se' tra nói seguida,
# nón sànza fìglio fuòr de la góla reco.
#
# ma più al vìso vien per li 'ncida,
# più luci, in su lo 'nferno sospeso,
# ma più splendor ch'ivi può da li 'nfida.
#
# de la bontà dél cielo, in sul préso
# dél duca, quàle in sul fòsso de la stélla
# ché vagheggiar nón ha la vìa lor reso;
#
# ma pòi ché imarivò la fiàmma bèlla,
# mi mosse, e fece cóntra ' sdegnosa,
# si lava mìa nél ciel rispósta spesla,
#
# nón èra disio, perche' sì nón disposa
# da la mìa vostra virtù nón mi race,
# che' nón mi volgea dir per altra dosa.
#
# ma sì cóme quéi ché veder si face,
# nón sapev'ei ché fu, prìa l'aere state,
# ma perche' nón atte, e sìe lucece,
#
# ma disse: parla, sì mìa brève e argute
# al vènia di qua ónde mi da la pélle
# per le cornìce dél ciel giù si raggiate.
#
# e quest'è ciò ché 'l móndo mi suole:
# più nón di qua ma già mài si distende,
# se nón fosse, stata è dél tùo vuole
#
# più si suoni quél là più e rendescende
# cón la mìa virtù s'elli ha lùi muta,
# se nón si voce, nón dovea s'accende.
#
# quésti nón vide, e risponder si ruta
# da le prime, che, se nón si mosterrol;
# ne' potesse ciò ch'a s.u.a. giunta,
#
# quàndo 'l dùca mìo dottor si perser,
# da ìndi mi fece, altre cón àttore,
# tal vuol ché tal fàme ch'i' vidi serperser.
#
# l'aspetto ben, ché pur cón àltro fòre
# s'elli al fondo, ché 'l vìso mi discerpi,
# nón mi discernesse, che' nón se' dimore.
#
# ma se la vìva giustìzia ché qui sperpi
# prìma ché i ràggi d'i fiori e la cida,
# e li òcchi ragion ché te si ribelpi.
#
# bèn è cóme ai colpi, ché da 'nvida,
# lo fiùme fiùme fiùme ch'è fàtto a colùi
# si riparèa dél sùo fiùme rifida?.
#
# ed elli a me: l'aspetto fu la velùi
# ché dél sùo voler suso, amar riso,
# giunse in dietro, e par me fàre lùi fue.
#
# al sómmo parlar m'inganna, e da guìso
# mi facea sì, ché nón parlàndo dura,
# rispuose: or se' tu più saper confiso.
#
# nón sai, ma pòco da se' la lucura
# sì che, per tórre vedùta nón s'aspetta,
# se tu se' se' trasmuta sìa più oscura.
#
# ed elli a me: più óltre nón si stretta
# bèn se' rispuose, e quéllo ché notali,
# pòi ché la mìa ruìna nón si metta.
#
# io sentia già da se' l'anime fattali,
# mi disse: dùnque ché se' a la levarzia
# s'avesse, e dùnque ché li àltri spali.
#
# nón ti dopo ch'io volsi per le gozia,
# ma più pòco ché 'l voler sì procede,
# nón pòco più da ché buona è negazia.
#
# ma se bèn è la maggior vòglia vede,
# ché mi rimase, e far la vìta còsa
# quél ché si fa segna quél ch'i' v'ho piede.
#
# io nón ce bèn dir vìso nón so pòsa
#                   model  temperature  ...  hendec_ratio  word_correctness
# id                                    ...
# 33  1_7_256_512_4_0_150          0.5  ...          0.95              0.52
#
# [1 rows x 6 columns]

# %% [markdown]
# ##Selecting best model for each metric

# %%
limit = 5

attributes = data.columns[2:]
best_ids = []

# extract best generations
bests = {a:[] for a in attributes}
for attribute in attributes:
  bests[attribute] = data.sort_values(by=attribute, ascending=False)[:limit]
  best_ids.extend(bests[attribute].index)

for attribute in list(bests):
  print("\n\ntop of {}:\n{}\n".format(attribute, "="*80))
  print(bests[attribute][["model", "temperature", attribute]].head())
# Out:
# top of struct:
# ================================================================================
#
#                      model  temperature  struct
# id
# 0      1_1_256_512_4_0_150          0.5     1.0
# 149     5_5_256_512_4_0_70          1.1     1.0
# 138  5_3_256_512_4_150_150          1.1     1.0
# 139  5_3_256_512_4_150_150          1.2     1.0
# 140  5_3_256_512_4_150_150          1.3     1.0
#
#
# top of rhymes:
# ================================================================================
#
#                    model  temperature  rhymes
# id
# 36   1_7_256_512_4_0_150          0.8   0.984
# 143   5_5_256_512_4_0_70          0.5   0.969
# 25   1_5_256_512_4_0_150          0.8   0.969
# 114  5_3_256_512_4_0_150          0.9   0.969
# 169  5_5_256_512_4_70_70          0.9   0.969
#
#
# top of hendec_ratio:
# ================================================================================
#
#                      model  temperature  hendec_ratio
# id
# 44     3_1_256_512_4_0_150          0.5          1.00
# 83     3_5_256_512_4_0_150          1.1          0.97
# 68   3_3_256_512_4_150_150          0.7          0.97
# 37     1_7_256_512_4_0_150          0.9          0.97
# 154    5_5_256_512_4_0_150          0.5          0.96
#
#
# top of word_correctness:
# ================================================================================
#
#                    model  temperature  word_correctness
# id
# 44   3_1_256_512_4_0_150          0.5              0.78
# 202  7_1_256_512_4_0_150          0.9              0.77
# 221  7_5_256_512_4_0_150          0.6              0.77
# 220  7_5_256_512_4_0_150          0.5              0.76
# 224  7_5_256_512_4_0_150          0.9              0.76

# %% [markdown]
# ##Find the best generated text by summing all the scores

# %%
sums_column = []
for i in range(len(data)):
  row_score = sum(data.iloc[i, 1:][["struct", "hendec_ratio", "rhymes", "word_correctness"]].values)
  sums_column.append([data.iloc[i].name,
                      data.iloc[i]["model"],
                      data.iloc[i]["temperature"],
                      row_score])

winners = pd.DataFrame(sums_column).sort_values(by=[3], ascending=False).drop(columns=0)[:limit]
winners.columns = ["model", "temperature", "final_score"]
winners
# Out:
#                    model  temperature  final_score
# 154  5_5_256_512_4_0_150          0.5        3.532
# 143   5_5_256_512_4_0_70          0.5        3.529
# 155  5_5_256_512_4_0_150          0.6        3.512
# 169  5_5_256_512_4_70_70          0.9        3.509
# 25   1_5_256_512_4_0_150          0.8        3.479

# %% [markdown]
# ##And the winners are...

# %%
data.iloc[winners.index.values]
# Out:
#                    model  temperature  ...  hendec_ratio  word_correctness
# id                                     ...
# 154  5_5_256_512_4_0_150          0.5  ...          0.96              0.65
# 143   5_5_256_512_4_0_70          0.5  ...          0.90              0.66
# 155  5_5_256_512_4_0_150          0.6  ...          0.96              0.63
# 169  5_5_256_512_4_70_70          0.9  ...          0.93              0.61
# 25   1_5_256_512_4_0_150          0.8  ...          0.93              0.58
#
# [5 rows x 6 columns]

# %%
for i in range(len(winners)):
  id = winners.iloc[i].name
  model = winners.iloc[i]["model"]
  temp = str(winners.iloc[i]["temperature"])
  score = winners.iloc[i]["final_score"]

  print("\n{}\nSCORE: {}\n".format("="*80, score))
  print_model(model, temp)
  print("\n{}\n{}\n{}\n".format("-"*40, data.iloc[id], "-"*40))
  print(get_text(model, temp))
# Out:
# ================================================================================
# SCORE: 3.532
#
#
# encoders	5
# decoders	5
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	0
# comedy epochs	150
# temperature	0.5
#
# ----------------------------------------
# model               5_5_256_512_4_0_150
# temperature                         0.5
# struct                                1
# rhymes                            0.922
# hendec_ratio                       0.96
# word_correctness                   0.65
# Name: 154, dtype: object
# ----------------------------------------
#
#
# àhi quànto a dir qual èra è còsa dùra
# ésta prote, e tal lòde óltre pensa,
# ché 'ntrati e vecchie, da l'altra richiusi alsura
#
# tòsto ché ne la mìa vòglia richiusa,
# ancor ti tolse, e cón le man beatrice
# quàndo vegnon posto, ancor mi fìa musa.
#
# i' dìco dopo i nostri mìlle passi mìlle
# quàndo la maria, e nón mólto mandura,
# mólto sarà di dio, quàndo le spalle!.
#
# o buòn maestro mio, buòn ti madura,
# se tu vuo' saperr, di ciò ch'io disiri
# per far sùo lòco óve tèmpo s'attura;
#
# sì che, per dilazion dél tùo disiri
# la fàccia mìa mente, in su la fàccia
# soffersi le braccia e più mi vèri spiri
#
# ànzi la guìda dél ciel, si disfaccia
# quéi dél sómmo domandò fa le sùe voci
# tra ' principio, a te la mìa faccia
#
# gridò: nón facer: chi tu naleràci
# nél quànto suso, ond'elli è dìo volto;
# se ciò m'ha fàtto ha tèrra li cafaci.
#
# ed elli a me: nessun mónte è raccolto
# la fàccia mìa è quél ché cón podesta,
# quàndo vuol ben, da li àltri ricolto.
#
# nùllo possibil più ché mài nón si mesta
# in nón pur io, ma rallarga ogne vigogna,
# tu se' o pensier cón un altrùi solesta.
#
# ónde più io vidi là dov'io rirogna,
# dissi: nón ti darò, che' tu ti medi
# pensa ché la pròda ónde ti rimagna?.
#
# e io, per colùi ché tu vuo' ch'io riedi,
# già nón è rispósto a salir per sì prego;
# e 'l maestro, ché nón sa chi tu vedi
#
# sì mi piaccia, ché l'ovra de la légo
# fu sì altra via, ne la drìtta zita;
# e fe' mal propinto, e da nostre priego
#
# pur ti può di là dóve sòn beatrita;
# che' la ménte mìa prender ciò si vede,
# e nón mi puose ch'ogne tòrto si dita.
#
# io tua ragiona, che' nón ti nasconde:
# tu da te, ché nón vedi sì mal lieto
# nél móndo chiàro ben, che' le nasconde.
#
# or quìndi tu ché nón sìe nòtte e fèto
# surge per drizzar, ché parean di vìva
# quàndo la ménte tua su per lo monteto.
#
# vidi, per tèmpo ché di quàttro riva,
# volgendo 'l viso, e di nói rimani,
# ché nón potea far le man si discriva,
#
# giunse 'l doloro; ìndi quéi lontani:
# voi ché nón vànno sceman ché sien volte,
# se nón si mùta de le vita cadani.
#
# allór si mosse, e nón da ricolte,
# ch'i' nól potea più óltre per lo stremo,
# tòsto è ricadde e più óltre si rivolte.
#
# un altro, ché nón sapeva per remo;
# nón mi ferse; e io vo' ché tu per gèlo
# ché dice più a quésto a nói tra 'mpemo.
#
# sì ti fer nél dùca mìo sì stelo,
# ch'i' caddi cóme 'l volge e la gràn peròta
# più tòsto ché 'l mìo profóndo a compelo.
#
# e qui si vedea per mìa memòria,
# per nón ch'i' perdei veder nél consìglio ,
# spìrito sono, e sì tra tua vittoria.
#
# io sarò nél prìmo dì ch'io mi preghi,
# io vidi lerò, ch'i' diss'io, ch'i' cado,
# al sùo per tèmpo tace, i si spieghi
#
# di ché tu se' pur nata quésto mondo:
# più nón mi ti derò, ma perche' disiri
# al pover che, nón posson trar nón prodo.
#
# dal primo, credo, inducendo in sifiri;
# e torna 'l quìnto dì e così duri,
# nél tùo salir nón di rìso ch'io viri.
#
# e 'l dùca mìo salir per s'inforri,
# che' 'l nóme di quél ch'è de la quàle,
# ma per quetar vuole, avvien ché tu scuri
#
# più a' primi, avvegna ch'è lor duole,
# e sì pien di stàta la tua men li aspetta
# la càrne gridò: ché tu nón ti duole.
#
# pensa la mìa dònna mosse lor fretta,
# che' nón pur al mìo già pianger ricosta,
# e disse: quàndo sia, a far distrutta.
#
# così beatrice, al cùi dì si costa,
# rispuose, e quàndo fìa piacer di pianta;
# poi, cóme frati, a far gràve costa.
#
# se l'alta lùce ché più là sù canta,
# io ti rivolsi al ciel de la mìa costa,
# queste che, cóme fu mòrta ché sì canta
#
# la nostra sustanza, ché mài nón tosta,
# pensa ché 'l sàvio duca, fu sì fòrte
# di colùi ché nón potea mài la costa.
#
# nón fu le pecorelle, sì lùnga mòrte
# va la grimanda, ché 'l grifóne ed esso,
# al càrro volse cóme a se' volger l, ;
#
# e un di loro, quàsi da ciel permesso,
# 'veni, sponsa, e sponsali da , sponde
# al càrro tier, e di lùi si messo.
#
# in su la gènte ch'al fùmmo si confonde
# di qua, dicendo: giovani 'l giuso!,
# già 'l qual, mi disse quelle sormonde.
#
# così ferra a vìsta ónde ti vien chiuso,
#
#
# ================================================================================
# SCORE: 3.529
#
#
# encoders	5
# decoders	5
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	0
# comedy epochs	70
# temperature	0.5
#
# ----------------------------------------
# model               5_5_256_512_4_0_70
# temperature                        0.5
# struct                               1
# rhymes                           0.969
# hendec_ratio                       0.9
# word_correctness                  0.66
# Name: 143, dtype: object
# ----------------------------------------
#
#
# àhi quànto a dir qual èra àspra e pura,
# ché ché ne sapete nón ha più per vélo
# ché 'l mal federe, ha più giù dura!
#
# nón mi par dir quél ch'io fedea velo,
# ch'io nón temea lì ché 'l vìso duro,
# ma per far di propria, se tu procelo.
#
# vieni a veder la mìa ménte è duro,
# dicendo: o verità ché tu ti move?
# quél ché ti dimostri amo.e tu vuo' muro.
#
# o ràbi è, ché tòsto nón giòve,
# se 'l mezzo, cóme cerchi in giù di sótto
# lo mìo maestro fece, e tànto giòve
#
# le mie libertram dal pàsto mìo fatto,
# per veder gràzia è quella ché ne scrive,
# ché l'altro sén va, e albia in mar ne ratto.
#
# ottacchero ebbè nome: e ne le scrive;
# e cominciò el, fu ché qui si dimostra
# ad ogne tórno cón s.u.a. larve.
#
# qui è ogne pàrte ónde si dimostra,
# rispuose: nón siete voi ché più m'ada,
# ma qual vuol ché 'l móndo si fece nostra
#
# la mìa coritàte disse: ché vada.
# posa, diss'io, sòn qui dal sòl bidiscesi
# pur ché più ha fàtta più fàre a la stràda
#
# nón sànza ségno mìo maestro fu tési
# in quésta stràda ché 'l mìo cor vede,
# cóme è l'uom ché nón fossero a nón tesi.
#
# e già veggendo 'l mìo sguàrdo il riede,
# più d'ogne parte, e più lo sguàrdo il rìso
# lo ciel da se', infin le coce vede.
#
# e quél ché tùtto sùo gìro di rìso
# facea la fiàmma d'amando, e par guàrda
# ché men di dìo sànza vìso nón fiso.
#
# nón corsè ché li òcchi sànza risponda,
# pòi disse: ancor è quél ché ti dimòro
# per queste parole, e ciò nón risponda.
#
# nón vidi mài maestro disse: un pòro
# ché 'l tùo parlar nón ti sìa mendùca
# nón ché 'l nóme di tal maestro moro.
#
# più nón ti può d'aver lo tùrchio luca,
# disse: guàrda cóme 'l grànde àlto pàsto
# nón ché per lo mónte giù per càrir merca
#
# le mie ond'elli ancora, e vedera posto:
# per ch'io ti farò ché nél vìso remo?.
# ed elli a me: se tu vuo' sarà costo.
#
# ed elli a me: la tua l'etterno remo,
# rispuose: la vostra tua nón è manifesto
# questi, ché di móndo ha più fàre amo?.
#
# ed elli a me: la tua creduta questo:
# costùi sòn queste da question ché 'l crede,
# prìma ché giunchi 'l risìglio ha disposto.
#
# per ch'io a me: se tu riguardi nón riede
# la tua misura, e cotal è menàto
# dal quàle in àela è già mài nón riede.
#
# nón vo' ché sappi ché ti facci guato,
# se nón còl sàngue cón li òcchi porti",
# acciò ch'ancor fa vien cón l'occhio più grato.
#
# e 'l pòco me, cóme l'uom portarti,
# si conve che, cóme dice, mi dimostra
# ciò ch'io nón so, ma per veder somorti.
#
# ma perche' qui ha ómbra e vìsta remostra,
# per la bontà ché da se' è la bontàte
# di quésti ha fàtta render la gràn nostra.
#
# per li diritti suoi, o pàrte salùte
# ché sòn nél viver lo duol ché sòn mosse,
# ma nón potea di piètra in igual tenute.
#
# sì ché la vìsta mia, ché nón s'asconse
# da s.u.a. matèra diètro a se' vegna
# ché nón si cuopre per lo vìso ónse.
#
# io nón posso già di lùi tornassegnare,
# ma quàndo fui prèsso a la fiàmma d'adamo,
# e tànto ché dìo còl vìso di pare.
#
# e qual è quél ché diètro da se' vìnmo
# più tòsto il còro èra ché 'l ciel vede,
# e nón so ne' chi è sèmpre al ciel remo,
#
# qual è colùi ché sùo vìso ardesse tènde
# nón le bianche tùtto se nón li 'nfolle,
# ne' sòn di nói le sùe reche concede.
#
# già eran li òcchi leon per molle,
# per lo ciel, ché di rètro aver d'amore,
# nón pur poter ne li òcchi d'i colle!.
#
# nón ti celer, per l'etterno splendore,
# chiron si volge; e quella è risposto,
# che, contra, cóme tu c'è più care".
#
# io nón posso ne c'è mestier sovrasto";
# per ch'io: maestro, ché 'l suol manifesto,
# sì ché par ché quìvi ha l'occhio riposto.
#
# ier, óltre parèa cón l'occhio mesto,
# mi si stava pronta e 'l sòl di taumante,
# ché nón disia, lettor; bèn cón questo.
#
# sòl cominciò el va ché più si stette;
# ma perch'io: ancor mi vive e nón compagni,
# rispuose: andar; ma tu veder conte:
#
# figlio, ché sòn qui cóme cagionitagni.
# ancor ti può nél lòco ónde ti vedi;
# e quél sòn beatrice, andando, fa via.
#
# pòi si rivolse beatrice, e nón vedi
# ne' miei òcchi ho la vérgine perduto,
# sì ché 'l veder fu d'i gràzia concedi.
#
# e cóme tu se': hài l'arsura confèrto
#
#
# ================================================================================
# SCORE: 3.512
#
#
# encoders	5
# decoders	5
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	0
# comedy epochs	150
# temperature	0.6
#
# ----------------------------------------
# model               5_5_256_512_4_0_150
# temperature                         0.6
# struct                                1
# rhymes                            0.922
# hendec_ratio                       0.96
# word_correctness                   0.63
# Name: 155, dtype: object
# ----------------------------------------
#
#
# àhi quànto a dir qual èra è còsa dùra
# ésta n'avea beatrice, ed ésso 'l làle
# si rivolge, e ha l'angel propria cura.
#
# io dìco di color ché tùtto ravalle,
# perche' màdre suo, mi disse: quél dimòno
# ché tu per venùto in sù li òcchi volle?
#
# s'io nón ti rimani, ma qui dimono,
# s'io sòn férmo tùtti 'l móndo più cara,
# e nón mólto quél ché fèrro ha dibuono.
#
# àlto intenzion lei, nón bàra qui s'insara,
# però ché tu nón li àltro potesti còrre
# se nón ché l'arte dóve 'l móndo nara.
#
# tu vuo' saper chi è in quésto corre,
# ché nón sìa già drìtta la ménte risposta
# di rètro a loco, e nón le parture;
#
# sì disse a noi: nón dopo sìa posta,
# ma nón dà, se 'l grifóne ed altra fèsta
# càrro volse se' cóme a se' sànza collosta;
#
# e un di loro, quàsi da nostre costa,
# quali, e si torna, ed èssere stélla
# ché le ciglia a ratene, e sù riposta!
#
# io nón sapeva prìma ché altra stella;
# e se 'l pàsso di cilor chiàra santa,
# sì ché la giustìzia tua vìa si stella.
#
# però nón sòn prèsso da lor la quanta,
# ma tànto gne lùce tra ' marti move,
# ché fu de l'uno àltro più àlto canta;
#
# che' sì a creder nón ti è nosterve,
# quàndo di còsa in su per li àltri pieni,
# chi foran férmo lo 'nferno ùna terve.
#
# sì quàndo i p ché 'l móndo gràn dere,
# ché punton crude, ancor ché fuòr dél lòco
# si mosse, e scùro cóme sùo vere,
#
# guàrda beatrìce è chi nél móndo lòco
# per li piedi, andando, si può luri,
# ne' quai colùi ché si fa cón quél gioco.
#
# nón ti fermar, quàndo tu di maggiori
# nél tùo fattóre e de li àltri beati",
# e nón li tempo, dir quinci, sigieri;
#
# montasi de l'argo de li àltri belti.
# e quél ché tu sappi ché de lo 'nferno
# quàndo scende da me, e sì li parti.
#
# siede àltro fàre al móndo è perfetto,
# e qui si chiamai; che' qui è te nòto
# a dir chi è sì prèsso a bène afetto?.
#
# e quélli a me: omài sarài sì devòto
# di dùe colpi, ché mi lasciò legare,
# se tu vuo' saper ch'i' di te ne fronto.
#
# quél ch'i' ho vedùto pòco più lasciare,
# nón fu maestro disse: or sòn venuto;
# e se tu nón ché 'l móndo dimandare.
#
# tu vuo' saperr, ma nón veder giuto:
# chi è quésto mondo, per tranquillar fede,
# così di lòco ché 'l sóle e di giunto.
#
# sì di ché 'n di gràve si ricede,
# li òcchi dopo 'l lòco il còrpo superbo,
# ché 'l mìo convien ché nùlla si vede.
#
# quàndo vedea colùi ché da nói cerbo,
# se nón porti tùo voler far nón giove,
# prìma vuol de li àltri da se' sofferbo.
#
# per nón si può, per àltro circunscrive,
# se tu vuo' saper canti li àltri giri,
# ché 'n quésto vidi, in cùi nón scrive.
#
# li àltri dùe nasi dopo più disiri
# nón tornàre a tal, però m'accors'io tutta;
# ma se nón fòsse de la dólce liri".
#
# tu se' pensa, cóme fu fràte cota,
# quél milo dél foco, accors'io, ed ecco
# chi sòla e ne la còsta è più lontata.
#
# ed elli a me: prìma è dólce carco,
# ché nói fossemo al piè de la réna torta,
# se 'l mìo voler più nostra ménte umanco.
#
# ed elli a me: el convien ché quésta vóta
# tu vuo' saper di qua già mài nón falla;
# ma qui nón fosse, mòdo ché m'inceta".
#
# tu vuo' saperr, ma perche' tu falla,
# sappi ché la man di là giù mi falla,
# per salir sù, e nessun nón si falla.
#
# se 'l móndo salir per la tua facella
# ché 'l dispósto a quél ché già de la cérchia
# ché già bagnava sóvra 'l ciel favella?.
#
# ónde queste parole, disse nón eschia,
# sànza può l'ora carne, al ché si chiuse
# a guìsa di colùi ché 'n se' amessa,
#
# in su le man diètro al móndo si chiuse.
# allóra podea ciascuna, e tànto fìso
# ché per lo lòco sóvra 'l natural fu.
#
# poi, cóme le pole in su l'orlo muso,
# che, per fuggir di quésta rìpa è piànta
# sànza fa parèa di loco, fu muso.
#
# io fui di sù la vida me compiuta
# al sàngue mondo, e dél sùo convento,
# ché nón si dovea ne la mòrte luta;
#
# e cóme fanno scema dél sùo convento
# li io véggio di loco, io nón divenne
# nòstro intelletto, e s'altra 'l sì contento.
#
# tu chi se' ché di là nostra sempine,
# nón sì ché possa bèn puoi la buona vò
# di ché nón m'è giudè, cón tànta spene.
#
# àlto nón sa, ma perche' nón ti mena
#
#
# ================================================================================
# SCORE: 3.509
#
#
# encoders	5
# decoders	5
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	70
# comedy epochs	70
# temperature	0.9
#
# ----------------------------------------
# model               5_5_256_512_4_70_70
# temperature                         0.9
# struct                                1
# rhymes                            0.969
# hendec_ratio                       0.93
# word_correctness                   0.61
# Name: 169, dtype: object
# ----------------------------------------
#
#
# àhi quànto a dir qual è còsa è dùra
# la selva, e cóme selvaggia e àspra e fòrte
# ché lo 'ntelletto, ed è tal vedura?
#
# tant'è amara, e vede la rimorte;
# ma già eravidi color ché 'l ciel fue,
# d'un àlto lor nón si fece ne' ritorte.
#
# e più nón so, parlàto a te si sùe
# dònna sì, ch'a la fàccia d'i mortali?,
# rispuose lui: sòn mésso ché già m'accune.
#
# ed elli a me: nessun volar tu cantali
# d'i mortali, e quànto fìa te ché move
# pàssi per leti, e portando sotti mali
#
# tànto ché dìo per àltri mi rimove,
# è chi posa, e nón volar fìa molto,
# quàndo di rètro a la ménte èra parmove.
#
# ed elli a me: quésto ti dìo volto,
# cóme tu se' venùto ché da la spuose;
# e pòi sappi ché 'l móndo fòsse volto,
#
# mi volsi al poeta, e sì le cospuose:
# taci e la mìa parlar saria fòsse tardi,
# sì cominciò elli, andando, spuose?".
#
# e io a lui: prìma ché tu vien bèn vedi,
# ché si puote sì bèn per voi seregi,
# prìma vuol ben, ch'el così parlò vedi.
#
# tu mi volsi al maestro sì mi distegi,
# parser: costà, se 'l vedi sopra,
# si levò e pòi ché dì nél móndo regi
#
# ché per lo sùo àpóre di talipra,
# ma per colùi ché 'l cinge pòrta riso,
# nón so ché se tu sarài se d'altro prìpra
#
# di quél ch'è dal sospètto dél móndo prìso
# ché dùe più ché di dìo parlar novi,
# sì com'elli ha dél ciel, difìno al riso.
#
# donna, diss'io, intórno al fin le movi:
# l'antico è formal ché tu li àltri chiavi
# per nói te ne porti, e quésto crovi.
#
# tùtti sarài tu per cu' io vivavi?,
# lo dùca mìo disio, e io mi rispuosi:
# maestro, ché 'l tèmpo nón è chi chiavi.
#
# e tu vedrai ché cose spiriti pàrsi
# lo dólce ber ché a la nostra sembiànza,
# nón so chi se', ma nón per dar carsi;
#
# che' già tutta fìa lor per altra fanza,
# sì ché vien più dél sùo risponder puote,
# e tu per seguitar più fàre a la stanza.
#
# s'elli è in etterni, ché si commote
# da quella róma ché dìo cose i vesi
# guàrda di sottile, e trovere lor dote
#
# ché nón torrà pianto, nón cói piède aborsi
# lo fóndo sùo pensier fa sì com'io reggi;
# e qual tu se' ché color li òcchi scarsi
#
# dal sùo figlio, disse il gridò: vegi:
# più è color ché re àltri nón vesti?.
# e prìa ché pòi si mangaro cói regi,
#
# assài mi parèa ché da quelle vesti:
# sì ch'io nón posso; e perch'io mi rispuosi
# quàndo di là da noi, ma venùto ancorsti.
#
# e sonò cóme ne li àltri sospesi,
# sì ch'io prendo tra ' cammiri d'i troiati
# e veder, cóme quéi di color vesi,
#
# ché tu per li àltri visi da beati.
# vedi ché sìe la lùce èra un pòco pòco
# già eran de li suoi terminar cón quanti
#
# dal serpente, e quella cón quésto lòco
# dal lùme ché 'l sùo làto si ragge,
# io nón so sìa giù sì folgor terco?.
#
# già e nói per fòrza di se' raccolange
# quella tré volte èra 'l còl mìo stuòlo
# e di cara, e tu, così dimange,
#
# ch'ei portò giù di buòn volére stuolo,
# pòi ver' maravigliar de le sùe corre,
# éllo è ch'un sento, e tùtto il rustuolo.
#
# e io: maestro, ché già nón si concorre,
# me vedi pente, e là sù le stelle,
# nón è ch'un pensier dilettor, si corre:
#
# nón ti maravigliar ciò ché lor favelle,
# dicendo: colui, e io a lui: chi 'l méco
# lo disìo ché più fàma nón ti favelle
#
# tu se' vedrai quàndo l'udir quant'è cieco
# dél tùo parlàre omài ché tu se' trascorsi,
# ché tu vedrai per tùo spirar lo cièco
#
# de le belle, e io grime novelli scorsi
# demo, e la più pietà ché 'l secóndo
# mi ricose, e pòi diètro a lor conforsi,
#
# lo maggior pàdre mio, di rètro profondo
# ché cominciai potea sì fatte far vélo
# lo ciel cùi tùtto sóle ha più tondo!.
#
# e nón rispuose: il sàvio vànno lùlo
# ché se nón fòsse lui, per nói m'infondi,
# tu già eran 'l mar lo dólce stuolo!.
#
# pòi ver' color li òcchi le sùe scindi
# la carte, ché 'l venir de la ratta,
# e i lor ne' rache, ne' fa ché scindi?.
#
# e i tre, ch'ascoltate la mòrte compunta,
# e i dùe più ché sòn te mi fuòr volti,
# e pòi ché volser lei, ed élla a giunta.
#
# ma già erava, e tùtti ti volti,
# sì ché pensando dissi "che per coduto,
# rispuos'io lui, mi smarri' in altro folti.
#
# e già agùsto nél mìo dólce duto,
#
#
# ================================================================================
# SCORE: 3.479
#
#
# encoders	1
# decoders	5
# dff     	256
# d_model 	512
# heads   	4
# prod epochs	0
# comedy epochs	150
# temperature	0.8
#
# ----------------------------------------
# model               1_5_256_512_4_0_150
# temperature                         0.8
# struct                                1
# rhymes                            0.969
# hendec_ratio                       0.93
# word_correctness                   0.58
# Name: 25, dtype: object
# ----------------------------------------
#
#
# àhi quànto a dir qual èra è còsara,
# quél ché 'l malvapènte ha tòlta le stelle
# ché mal temendo, il móndo fece nara.
#
# queste parole, e nón saràn quelle stelle
# ché la virtù mia, ché nél móndo secónte
# più ché giugne còsa nón ha più fiammelle.
#
# queste sòn io, e nón se più profonte
# ché lì è crìsto tùtto 'l tèmpo questo,
# più gràve tèmpo ché 'n quésta pàrte frónte
#
# ch'ei ponesse far di rètro a me difesto,
# pensa la s.u.a. volontà divera,
# in ciò ché di venir fu già sì desto.
#
# io fui la cagion ché per lo spera;
# e se 'l volger mìo dì a commosse,
# quàndo è di giù dél tròppo si disira.
#
# vìvo è più lumi, ché nón pur mosse
# dal tèmpo già per fuggir per la 'nstorma,
# sì ché giunti sùo dottor nón mi fosse;
#
# e perche' a dìo voi alcuna riforma,
# convien ché 'l màla ch'a la vìva spense,
# ché da se' sópra 'l valór mi s'accorma.
#
# un pòco attese, e pòi da lùi pense,
# disse, per lui, foràto è più mondo,
# disse lui, perche' 'l na e tu ti pense.
#
# nón veder ché 'l pregàto nón rispondo,
# ma quella è pòsa per me per li piedi
# più e men va ché prìa ché dolendo.
#
# e cèrto ché sòl da me si vededi,
# mi volsi al saperr, ch'io li àltri beati,
# e dissi: io sòn le ci così piedi.
#
# li òcchi miei nón ti verrà soffolti;
# e se la mìa virtù, pur a tànto indì
# sóvra 'l còrpo sòl tra l'ultimo s'ascolti.
#
# e prìma ch'io fossi vidi ch'io le fida
# nél tùo pote, e già m'avea 'l vìso
# per la fàccia ch'io sóvra qui nón ricorda,
#
# mi trasse lei, e pòi riguardar rigiùso
# quél ch'i' passai per la réte si riva,
# dicendo: omè, vedi ch'io ti richiuso!.
#
# se 'l maestro; e quésto móndo prova,
# mi disse: quél ver de la vìta spenta,
# se li àltri sòn di là u' la prova.
#
# la ràsta ché giacque è per la lenta,
# disse, di parlare, nón è più lume;
# ma qui però ché 'l móndo fu talenta.
#
# di quésta ne' piedi, fu così venume
# sén vànno fòsse ché 'n fòco si vede,
# ma di voi ché da la còrda produme,
#
# nón è per lo lòco dov'io più piede:
# nón è ra cóme l'uom ché sùo tacerte;
# ma mìa mente, a le cose comvede.
#
# méntre ché mìa dònna fu fàtta scherte,
# sànza ver' me, e pòscia di tèmpo fàre
# di te, e d'ogne bèn mover mi punte.
#
# lo sùo sàngue mio, ché mover soccorre
# ogne ge a ciel, ch'io dirò pur compiedi,
# tu vuo' ché 'l saper qui stésso soccorre.
#
# tu se' di quéi ché tu se' bèn vedi,
# però ché 'l ber fu per lo tùo sguàrdo
# sì ché i pochi tu prìa ché di credi
#
# tòsto ché 'l càrro d'esto caciò tardo,
# ma 'n parlarmi, in volar si discerna,
# ché se 'l fòsse prìmo è bonta guardo.
#
# e 'l vìso mìo cedere e più perpièna
# girando 'l viso, ché pur a l'alta tue
# vìa ché ne la sonno prìa mi mena.
#
# véro e è nembròtto per lo fùmmo tue.
# così un linguàggio nél móndo nón aluto,
# così ché 'l parlar più larghézza rispondo.
#
# pòscia nón sìa pur virgilio 'l duto,
# ch'io cesarei per lo sùo maggior grazia,
# ché nón sa di là ne' per me compiuto.
#
# tu credi ché a man dèstra si sazia,
# le luci sùe nél mèzzo re è gagno,
# tal ché l'anima è sòl cón tal saspazia.
#
# e se le suòre prìa ché da vegno,
# quebuona cera, e cantava le fe' giàde
# un crudel, ché di natùra di vegno.
#
# già eran li àltri sótto i suoi cede,
# a la mìa dònna mia; ma quella fesse
# ché la mìa tìra cantàre è serede.
#
# e se la ménte tua vìa mi fesse,
# per mìlle genti, e splenrava quél pùnto,
# ché dél fàtto tùo véro e nón si cesse.
#
# quìndi s'invegnar, ché ciascun si compunto
# cói cari fui de l'alto ché qui bruscia,
# ed elli a me: prìma d'alcuna è giunto.
#
# quél giù o nàto fìa per cùi tu luscia
# di quél ch'i' dìco tal, ché nón divenne
# ché nón se' tu più nón lór fu cuscia?.
#
# e 'l dùca mìo fràte mi ritenne,
# mi disse: quél conosce, e quél valóre
# ché tu mi se 'nviscai parven venne..
#
# quél mi ricorava 'n quél ché mi fòre
# ond'uscì 'l teme, e tai sànza seme?
# quél ché 'l nóme tùo dovrebbe d'amore.
#
# là dov'io più mi fe' sì pien di come
# quél ché più caro, e più nón si stànno
# dal móndo sùo maestro mio, li come.
#
# io fui di lùme il móndo ché l'usanno,
